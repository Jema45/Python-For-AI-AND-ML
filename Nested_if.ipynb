# %% [markdown]
# <a href="https://colab.research.google.com/github/Jema45/Python-For-AI-AND-ML/blob/main/Nested_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Customer_name = input("Enter Username: ")
loan_history = False
Standing_capital = int(input("Enter your standing capital, it should not be less than 100k"))
Email = input("Enter your Email:")
address = input("Enter your address:")
Bank_account = int(input("Enter your bank account: "))
Bank_name = str(input("Enter your bank Name:"))
Gender = input("Enter your gender(male/female):")
Business_Type = input("Enter your business type:")

if Standing_capital >= 100000:
  if loan_history == False:
    print("Loan approved")
  else:
      print("Loan not approved")
else:
     print("standing capital too low")
# Out:
# Enter Username: Jema
# Enter your standing capital, it should not be less than 100k200000
# Enter your Email:jema@email.com
# Enter your address:Shelter
# Enter your bank account: 2288997766
# Enter your bank Name:Opay
# Enter your gender(male/female):Female
# Enter your business type:Computer Scientist
# Loan approved
