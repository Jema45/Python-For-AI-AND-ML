# %% [markdown]
# <a href="https://colab.research.google.com/github/Jema45/Python-For-AI-AND-ML/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 20

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Eligible to vote

# %%
children = {
    "child1": {
        "name": "David",
        "age": 10
    },

    "child2": {
        "name": "Sarah",
        "age": 8
    },

    "child3": {
        "name": "Daniel",
        "age": 6
    }
}

print(children)
# Out:
# {'child1': {'name': 'David', 'age': 10}, 'child2': {'name': 'Sarah', 'age': 8}, 'child3': {'name': 'Daniel', 'age': 6}}

# %%
age = 15

if age >= 18:
    print("Adult")
else:
    print("Not an adult")
# Out:
# Not an adult
