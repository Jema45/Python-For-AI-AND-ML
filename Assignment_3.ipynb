# %% [markdown]
# <a href="https://colab.research.google.com/github/Jema45/Python-For-AI-AND-ML/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "Jemima" and password == "1234":
    print("Login successful")
else:
    print("Login unsuccessful")
# Out:
# Enter username: Jemima
# Enter password: 1234
# Login successful

# %%
username = input("Enter username: ")
age = input("Enter age: ")
if username == "Timmy" or age == "21" :
  print("Login valid")
else:
  print("Login Invalid")
# Out:
# Enter username: Mimi
# Enter age: 21
# Login valid
